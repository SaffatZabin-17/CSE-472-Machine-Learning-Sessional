# %%
import pandas as pd
import numpy as np

dataframe_train = pd.read_csv("Datasets/adult/adult.data", header=None)

dataframe_test = pd.read_csv("Datasets/adult/adult.test", header=None)

column_names = ['Age', 
                'Workclass', 
                'fnlwgt', 
                'Education', 
                'Education-num', 
                'Marital status', 
                'Occupation', 
                'Relationship', 
                'Race', 
                'Sex', 
                'Capital gain', 
                'Capital loss', 
                'Hours per week', 
                'Native Country',
                'Income' ]

dataframe_train.columns = column_names

dataframe_test.columns = column_names

dataframe_train.head(100)
# Out:
#     Age          Workclass  fnlwgt      Education  Education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# ..  ...                ...     ...            ...            ...
# 95   29          Local-gov  115585   Some-college             10
# 96   48   Self-emp-not-inc  191277      Doctorate             16
# 97   37            Private  202683   Some-college             10
# 98   48            Private  171095     Assoc-acdm             12
# 99   32        Federal-gov  249409        HS-grad              9
#
#          Marital status          Occupation    Relationship    Race      Sex  \
# 0         Never-married        Adm-clerical   Not-in-family   White     Male
# ...

# %%
dataframe_test.head(100)
# Out:
#     Age   Workclass  fnlwgt      Education  Education-num  \
# 0    25     Private  226802           11th              7
# 1    38     Private   89814        HS-grad              9
# 2    28   Local-gov  336951     Assoc-acdm             12
# 3    44     Private  160323   Some-college             10
# 4    18           ?  103497   Some-college             10
# ..  ...         ...     ...            ...            ...
# 95   20     Private  479296        HS-grad              9
# 96   25     Private  235218      Bachelors             13
# 97   49     Private  164877           10th              6
# 98   59     Private  272087        HS-grad              9
# 99   20     Private  169699        HS-grad              9
#
#          Marital status          Occupation    Relationship    Race      Sex  \
# 0         Never-married   Machine-op-inspct       Own-child   Black     Male
# 1    Married-civ-spouse     Farming-fishing         Husband   White     Male
# ...

# %%
dataframe_train.shape
# Out:
# (32561, 15)

# %%
dataframe_test.shape
# Out:
# (16281, 15)

# %%
dataframe_train.describe()
# Out:
#                 Age        fnlwgt  Education-num  Capital gain  Capital loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours per week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
dataframe_test.describe()
# Out:
#                 Age        fnlwgt  Education-num  Capital gain  Capital loss  \
# count  16281.000000  1.628100e+04   16281.000000  16281.000000  16281.000000
# mean      38.767459  1.894357e+05      10.072907   1081.905104     87.899269
# std       13.849187  1.057149e+05       2.567545   7583.935968    403.105286
# min       17.000000  1.349200e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.167360e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.778310e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.383840e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   3770.000000
#
#        Hours per week
# count    16281.000000
# mean        40.392236
# std         12.479332
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
dataframe_train.isnull().sum()
# Out:
# Age               0
# Workclass         0
# fnlwgt            0
# Education         0
# Education-num     0
# Marital status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital gain      0
# Capital loss      0
# Hours per week    0
# Native Country    0
# Income            0
# dtype: int64

# %%
dataframe_train.duplicated().sum()
# Out:
# np.int64(24)

# %%
dataframe_train = dataframe_train.drop_duplicates()

dataframe_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataframe_test.isnull().sum()
# Out:
# Age               0
# Workclass         0
# fnlwgt            0
# Education         0
# Education-num     0
# Marital status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital gain      0
# Capital loss      0
# Hours per week    0
# Native Country    0
# Income            0
# dtype: int64

# %%
dataframe_test.duplicated().sum()
# Out:
# np.int64(5)

# %%
dataframe_test = dataframe_test.drop_duplicates()

dataframe_test.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataframe_train.columns
# Out:
# Index(['Age', 'Workclass', 'fnlwgt', 'Education', 'Education-num',
#        'Marital status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital gain', 'Capital loss', 'Hours per week', 'Native Country',
#        'Income'],
#       dtype='object')

# %%
def find_columns_with_question_mark(dataframe):
    columns_with_question_mark = []

    for column in dataframe.columns:
        if dataframe[column].astype(str).str.strip().eq('?').any():
            columns_with_question_mark.append(column)

    return columns_with_question_mark

columns_with_question_mark = find_columns_with_question_mark(dataframe_train)
print(columns_with_question_mark)
# Out:
# ['Workclass', 'Occupation', 'Native Country']

# %%
dataframe_train.replace(to_replace=r'^\s*\?\s*$', value=np.nan, regex=True, inplace=True)

columns_with_question_mark = find_columns_with_question_mark(dataframe_train)

print(columns_with_question_mark)
# Out:
# []

# %%
dataframe_train.head(100)
# Out:
#     Age          Workclass  fnlwgt      Education  Education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# ..  ...                ...     ...            ...            ...
# 95   29          Local-gov  115585   Some-college             10
# 96   48   Self-emp-not-inc  191277      Doctorate             16
# 97   37            Private  202683   Some-college             10
# 98   48            Private  171095     Assoc-acdm             12
# 99   32        Federal-gov  249409        HS-grad              9
#
#          Marital status          Occupation    Relationship    Race      Sex  \
# 0         Never-married        Adm-clerical   Not-in-family   White     Male
# ...

# %%
def replace_nan(dataframe):
    for column in dataframe.columns:
        if dataframe[column].isnull().any():
            if pd.api.types.is_numeric_dtype(dataframe[column]):
                mean_value = dataframe[column].mean()
                dataframe[column].fillna(mean_value, inplace=True)
            else: 
                mode_value = dataframe[column].mode()[0]
                dataframe[column].fillna(mode_value, inplace=True)

    return dataframe

dataframe_train = replace_nan(dataframe_train)

dataframe_train.head(100)
# Out:
# /tmp/ipykernel_70296/1826441263.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe[column].fillna(mode_value, inplace=True)
#     Age          Workclass  fnlwgt      Education  Education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# ...

# %%
columns_with_question_mark = find_columns_with_question_mark(dataframe_test)

dataframe_test.replace(to_replace=r'^\s*\?\s*$', value=np.nan, regex=True, inplace=True)

columns_with_question_mark = find_columns_with_question_mark(dataframe_test)

print(columns_with_question_mark)
# Out:
# []

# %%
dataframe_test.head(100)
# Out:
#     Age   Workclass  fnlwgt      Education  Education-num  \
# 0    25     Private  226802           11th              7
# 1    38     Private   89814        HS-grad              9
# 2    28   Local-gov  336951     Assoc-acdm             12
# 3    44     Private  160323   Some-college             10
# 4    18         NaN  103497   Some-college             10
# ..  ...         ...     ...            ...            ...
# 95   20     Private  479296        HS-grad              9
# 96   25     Private  235218      Bachelors             13
# 97   49     Private  164877           10th              6
# 98   59     Private  272087        HS-grad              9
# 99   20     Private  169699        HS-grad              9
#
#          Marital status          Occupation    Relationship    Race      Sex  \
# 0         Never-married   Machine-op-inspct       Own-child   Black     Male
# 1    Married-civ-spouse     Farming-fishing         Husband   White     Male
# ...

# %%
dataframe_test = replace_nan(dataframe_test)

dataframe_test.head(100)
# Out:
# /tmp/ipykernel_70296/1826441263.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe[column].fillna(mode_value, inplace=True)
#     Age   Workclass  fnlwgt      Education  Education-num  \
# 0    25     Private  226802           11th              7
# 1    38     Private   89814        HS-grad              9
# 2    28   Local-gov  336951     Assoc-acdm             12
# 3    44     Private  160323   Some-college             10
# 4    18     Private  103497   Some-college             10
# ...

# %%
features_train = dataframe_train.drop('Income', axis=1)
target_train = dataframe_train['Income']

features_test = dataframe_test.drop('Income', axis=1)
target_test = dataframe_test['Income']

# %%
features_train
# Out:
#        Age          Workclass  fnlwgt    Education  Education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
target_train
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32556     <=50K
# 32557      >50K
# 32558     <=50K
# 32559     <=50K
# 32560      >50K
# Name: Income, Length: 32537, dtype: object

# %%
features_test
# Out:
#        Age      Workclass  fnlwgt      Education  Education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 4       18        Private  103497   Some-college             10
# ...    ...            ...     ...            ...            ...
# 16276   39        Private  215419      Bachelors             13
# 16277   64        Private  321403        HS-grad              9
# 16278   38        Private  374983      Bachelors             13
# 16279   44        Private   83891      Bachelors             13
# 16280   35   Self-emp-inc  182148      Bachelors             13
#
#             Marital status          Occupation     Relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# 1       Married-civ-spouse     Farming-fishing          Husband
# ...

# %%
target_test
# Out:
# 0         <=50K.
# 1         <=50K.
# 2          >50K.
# 3          >50K.
# 4         <=50K.
#           ...
# 16276     <=50K.
# 16277     <=50K.
# 16278     <=50K.
# 16279     <=50K.
# 16280      >50K.
# Name: Income, Length: 16276, dtype: object

# %%
for column in features_train.columns:
    print(column)
    print(dataframe_train[column].dtype)
# Out:
# Age
# int64
# Workclass
# object
# fnlwgt
# int64
# Education
# object
# Education-num
# int64
# Marital status
# object
# Occupation
# object
# Relationship
# object
# Race
# object
# Sex
# object
# Capital gain
# int64
# Capital loss
# int64
# Hours per week
# int64
# Native Country
# object

# %%
label_encoding_columns_features_train = []
one_hot_encoding_columns_features_train = []
binary_columns_features_train = []

for column in features_train:
    if features_train[column].dtype == object:
        print(column)
        unique_values = features_train[column].unique()
        unique_count = features_train[column].nunique()
        if unique_count == 2:
            if features_train[column].dropna().isin([0, 1]).all():
                binary_columns_features_train.append(column)
            else:
                label_encoding_columns_features_train.append(column)
        else :
            one_hot_encoding_columns_features_train.append(column)
        print(unique_values)
        print(unique_count)
# Out:
# Workclass
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' Self-emp-inc' ' Without-pay' ' Never-worked']
# 8
# Education
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# 16
# Marital status
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# 7
# Occupation
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# 14
# Relationship
# [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# 6
# Race
# [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# 5
# Sex
# [' Male' ' Female']
# ...

# %%
label_encoding_columns_features_train
# Out:
# ['Sex']

# %%
one_hot_encoding_columns_features_train
# Out:
# ['Workclass',
#  'Education',
#  'Marital status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Native Country']

# %%
binary_columns_features_train
# Out:
# []

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for column in label_encoding_columns_features_train:
    features_train[column] = encoder.fit_transform(features_train[column])

features_train.head(100)
# Out:
#     Age          Workclass  fnlwgt      Education  Education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# ..  ...                ...     ...            ...            ...
# 95   29          Local-gov  115585   Some-college             10
# 96   48   Self-emp-not-inc  191277      Doctorate             16
# 97   37            Private  202683   Some-college             10
# 98   48            Private  171095     Assoc-acdm             12
# 99   32        Federal-gov  249409        HS-grad              9
#
#          Marital status          Occupation    Relationship    Race  Sex  \
# 0         Never-married        Adm-clerical   Not-in-family   White    1
# ...

# %%
features_train_encoded = pd.get_dummies(features_train, columns=one_hot_encoding_columns_features_train).astype(int)

# %%
one_hot_encoded_columns_features_train = []

for column in features_train_encoded.columns:
    if features_train_encoded[column].nunique() == 2 and column not in (label_encoding_columns_features_train + binary_columns_features_train):
        if features_train_encoded[column].between(0, 1).all():
            one_hot_encoded_columns_features_train.append(column)

one_hot_encoded_columns_features_train
# Out:
# ['Workclass_ Federal-gov',
#  'Workclass_ Local-gov',
#  'Workclass_ Never-worked',
#  'Workclass_ Private',
#  'Workclass_ Self-emp-inc',
#  'Workclass_ Self-emp-not-inc',
#  'Workclass_ State-gov',
#  'Workclass_ Without-pay',
#  'Education_ 10th',
#  'Education_ 11th',
#  'Education_ 12th',
#  'Education_ 1st-4th',
#  'Education_ 5th-6th',
#  'Education_ 7th-8th',
#  'Education_ 9th',
#  'Education_ Assoc-acdm',
#  'Education_ Assoc-voc',
#  'Education_ Bachelors',
#  'Education_ Doctorate',
#  'Education_ HS-grad',
#  'Education_ Masters',
#  'Education_ Preschool',
#  'Education_ Prof-school',
#  'Education_ Some-college',
#  'Marital status_ Divorced',
#  'Marital status_ Married-AF-spouse',
#  'Marital status_ Married-civ-spouse',
#  'Marital status_ Married-spouse-absent',
#  'Marital status_ Never-married',
#  'Marital status_ Separated',
#  'Marital status_ Widowed',
#  'Occupation_ Adm-clerical',
#  'Occupation_ Armed-Forces',
#  'Occupation_ Craft-repair',
# ...

# %%
excluded_columns = one_hot_encoded_columns_features_train + label_encoding_columns_features_train + binary_columns_features_train

columns_to_scale = [col for col in features_train_encoded.columns if col not in excluded_columns]

columns_to_scale
# Out:
# ['Age',
#  'fnlwgt',
#  'Education-num',
#  'Capital gain',
#  'Capital loss',
#  'Hours per week']

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

def scaling(df, scaling_type):
    if scaling_type == 0:
        scaler = StandardScaler()
    else:
        scaler = MinMaxScaler()

    features_scale = scaler.fit_transform(df[columns_to_scale])

    return features_scale

features_scale = scaling(features_train_encoded, 1)

features_train_encoded[columns_to_scale] = features_scale

features_train_encoded
# Out:
#             Age    fnlwgt  Education-num  Sex  Capital gain  Capital loss  \
# 0      0.301370  0.044302       0.800000    1      0.021740           0.0
# 1      0.452055  0.048238       0.800000    1      0.000000           0.0
# 2      0.287671  0.138113       0.533333    1      0.000000           0.0
# 3      0.493151  0.151068       0.400000    1      0.000000           0.0
# 4      0.150685  0.221488       0.800000    0      0.000000           0.0
# ...         ...       ...            ...  ...           ...           ...
# 32556  0.136986  0.166404       0.733333    0      0.000000           0.0
# 32557  0.315068  0.096500       0.533333    1      0.000000           0.0
# 32558  0.561644  0.094827       0.533333    0      0.000000           0.0
# 32559  0.068493  0.128499       0.533333    1      0.000000           0.0
# 32560  0.479452  0.187203       0.533333    0      0.150242           0.0
#
#        Hours per week  Workclass_ Federal-gov  Workclass_ Local-gov  \
# ...

# %%
target_train = encoder.fit_transform(target_train)

target_train
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
target_test = encoder.fit_transform(target_test)

target_test
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
label_encoding_columns_features_test = label_encoding_columns_features_train
one_hot_encoding_columns_features_test = one_hot_encoding_columns_features_train
binary_columns_features_test = binary_columns_features_train

# %%
encoder = LabelEncoder()

for column in label_encoding_columns_features_test:
    features_test[column] = encoder.fit_transform(features_test[column])

features_test.head(100)
# Out:
#     Age   Workclass  fnlwgt      Education  Education-num  \
# 0    25     Private  226802           11th              7
# 1    38     Private   89814        HS-grad              9
# 2    28   Local-gov  336951     Assoc-acdm             12
# 3    44     Private  160323   Some-college             10
# 4    18     Private  103497   Some-college             10
# ..  ...         ...     ...            ...            ...
# 95   20     Private  479296        HS-grad              9
# 96   25     Private  235218      Bachelors             13
# 97   49     Private  164877           10th              6
# 98   59     Private  272087        HS-grad              9
# 99   20     Private  169699        HS-grad              9
#
#          Marital status          Occupation    Relationship    Race  Sex  \
# 0         Never-married   Machine-op-inspct       Own-child   Black    1
# 1    Married-civ-spouse     Farming-fishing         Husband   White    1
# ...

# %%
features_test_encoded = pd.get_dummies(features_test, columns=one_hot_encoding_columns_features_test).astype(int)

features_test_encoded
# Out:
#        Age  fnlwgt  Education-num  Sex  Capital gain  Capital loss  \
# 0       25  226802              7    1             0             0
# 1       38   89814              9    1             0             0
# 2       28  336951             12    1             0             0
# 3       44  160323             10    1          7688             0
# 4       18  103497             10    0             0             0
# ...    ...     ...            ...  ...           ...           ...
# 16276   39  215419             13    0             0             0
# 16277   64  321403              9    1             0             0
# 16278   38  374983             13    1             0             0
# 16279   44   83891             13    1          5455             0
# 16280   35  182148             13    1             0             0
#
#        Hours per week  Workclass_ Federal-gov  Workclass_ Local-gov  \
# 0                  40                       0                     0
# ...

# %%
one_hot_encoded_columns_features_test = []

for column in features_test_encoded.columns:
    if features_test_encoded[column].nunique() == 2 and column not in (label_encoding_columns_features_test + binary_columns_features_test):
        if features_test_encoded[column].between(0, 1).all():
            one_hot_encoded_columns_features_test.append(column)

one_hot_encoded_columns_features_test
# Out:
# ['Workclass_ Federal-gov',
#  'Workclass_ Local-gov',
#  'Workclass_ Never-worked',
#  'Workclass_ Private',
#  'Workclass_ Self-emp-inc',
#  'Workclass_ Self-emp-not-inc',
#  'Workclass_ State-gov',
#  'Workclass_ Without-pay',
#  'Education_ 10th',
#  'Education_ 11th',
#  'Education_ 12th',
#  'Education_ 1st-4th',
#  'Education_ 5th-6th',
#  'Education_ 7th-8th',
#  'Education_ 9th',
#  'Education_ Assoc-acdm',
#  'Education_ Assoc-voc',
#  'Education_ Bachelors',
#  'Education_ Doctorate',
#  'Education_ HS-grad',
#  'Education_ Masters',
#  'Education_ Preschool',
#  'Education_ Prof-school',
#  'Education_ Some-college',
#  'Marital status_ Divorced',
#  'Marital status_ Married-AF-spouse',
#  'Marital status_ Married-civ-spouse',
#  'Marital status_ Married-spouse-absent',
#  'Marital status_ Never-married',
#  'Marital status_ Separated',
#  'Marital status_ Widowed',
#  'Occupation_ Adm-clerical',
#  'Occupation_ Armed-Forces',
#  'Occupation_ Craft-repair',
# ...

# %%
excluded_columns = one_hot_encoded_columns_features_test + label_encoding_columns_features_test + binary_columns_features_test

columns_to_scale = [col for col in features_test_encoded.columns if col not in excluded_columns]

columns_to_scale
# Out:
# ['Age',
#  'fnlwgt',
#  'Education-num',
#  'Capital gain',
#  'Capital loss',
#  'Hours per week']

# %%
features_scale = scaling(features_test_encoded, 1)

features_test_encoded[columns_to_scale] = features_scale

features_test_encoded
# Out:
#             Age    fnlwgt  Education-num  Sex  Capital gain  Capital loss  \
# 0      0.109589  0.144430       0.400000    1      0.000000           0.0
# 1      0.287671  0.051677       0.533333    1      0.000000           0.0
# 2      0.150685  0.219011       0.733333    1      0.000000           0.0
# 3      0.369863  0.099418       0.600000    1      0.076881           0.0
# 4      0.013699  0.060942       0.600000    0      0.000000           0.0
# ...         ...       ...            ...  ...           ...           ...
# 16276  0.301370  0.136723       0.800000    0      0.000000           0.0
# 16277  0.643836  0.208484       0.533333    1      0.000000           0.0
# 16278  0.287671  0.244762       0.800000    1      0.000000           0.0
# 16279  0.369863  0.047666       0.800000    1      0.054551           0.0
# 16280  0.246575  0.114195       0.800000    1      0.000000           0.0
#
#        Hours per week  Workclass_ Federal-gov  Workclass_ Local-gov  \
# ...

# %%
features_test_encoded_columns = set(features_test_encoded.columns)

features_train_encoded_columns = set(features_train_encoded.columns)

missing_in_test = features_train_encoded_columns - features_test_encoded_columns

missing_in_train = features_test_encoded_columns - features_train_encoded_columns

# %%
missing_in_test
# Out:
# {'Native Country_ Holand-Netherlands'}

# %%
missing_in_train
# Out:
# set()

# %%
features_train = pd.DataFrame(features_train_encoded, columns=features_train_encoded.columns)
target_train = pd.DataFrame(target_train, columns=['Income'])

features_test = pd.DataFrame(features_test_encoded, columns=features_test_encoded.columns)
target_test = pd.DataFrame(target_test, columns=['Income'])
features_test = features_test.reindex(columns=features_train.columns, fill_value=0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(features_train, target_train)

y_pred = model.predict(features_test)

accuracy_library_LR = accuracy_score(y_pred, target_test)

accuracy_library_LR
# Out:
# /home/saffat/.local/lib/python3.9/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8503932170066355

# %%
from logistic_regression import _LogisticRegression


features_train_np = features_train.to_numpy()
target_train_np = target_train.to_numpy()

model_self = _LogisticRegression()

model.fit(features_train_np, target_train_np)
y_pred = model.predict(features_test)
# Out:
# /home/saffat/.local/lib/python3.9/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/saffat/.local/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve, auc

accuracy_LR = accuracy_score(y_pred, target_test)

sensitivity_LR = recall_score(y_pred, target_test)

tn, tp, fn, fp = confusion_matrix(y_pred, target_test).ravel()
specificity_LR = tn / (tn + fp)

precision_LR = precision_score(y_pred, target_test)

f1_LR = f1_score(y_pred, target_test)

auroc_LR = roc_auc_score(y_pred, target_test)

precision_vals, recall_vals, _ = precision_recall_curve(y_pred, target_test)
aupr_LR = auc(recall_vals, precision_vals)

standard_deviation_LR = np.std(y_pred, ddof=0)

# %%
from bagging_ensemble import _BaggingEnsemble

bagging_ensemble_model = _BaggingEnsemble()

bagging_ensemble_model.fit(features_train, target_train)

all_preds = bagging_ensemble_model.predict_all(features_test)

final_pred = bagging_ensemble_model.final_prediction(features_test)

# %%
accuracy_bagging = accuracy_score(final_pred, target_test)

sensitivity_bagging = recall_score(final_pred, target_test)

tn, tp, fn, fp = confusion_matrix(final_pred, target_test).ravel()
specificity_bagging = tn / (tn + fp)

precision_bagging = precision_score(final_pred, target_test)

f1_bagging = f1_score(final_pred, target_test)

auroc_bagging = roc_auc_score(final_pred, target_test)

precision_vals, recall_vals, _ = precision_recall_curve(final_pred, target_test)
aupr_bagging = auc(recall_vals, precision_vals)

# %%
standard_deviation_bagging = np.std(final_pred, ddof=0)

standard_deviation_bagging
# Out:
# np.float64(0.22086384648868904)

# %%
from stacking_ensemble import _StackingEnsemble

base_model = _LogisticRegression()
meta_model = _LogisticRegression()

stacking_ensemble = _StackingEnsemble(base_model, meta_model)

stacking_ensemble.fit(features_train, target_train)

final_prediction = stacking_ensemble.predict(features_test)

# %%
stacking_ensemble.plot_violin_plots()
# Out:
# /media/saffat/Work/VSCode/CSE 472/Offline 2/stacking_ensemble.py:82: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Metric', y='Score', data=melted_metrics_df, inner="point", palette=palette)

# %%
accuracy_stacking = accuracy_score(final_prediction, target_test)

sensitivity_stacking = recall_score(final_prediction, target_test)

tn, tp, fn, fp = confusion_matrix(final_prediction, target_test).ravel()
specificity_stacking = tn / (tn + fp)

precision_stacking = precision_score(final_prediction, target_test)

f1_stacking = f1_score(final_prediction, target_test)

auroc_stacking = roc_auc_score(final_prediction, target_test)

precision_vals, recall_vals, _ = precision_recall_curve(final_prediction, target_test)
aupr_stacking = auc(recall_vals, precision_vals)

# %%
standard_deviation_stacking = np.std(final_prediction, ddof=0)

standard_deviation_stacking
# Out:
# np.float64(0.23152160315889034)

# %%
metrics = {
    "Accuracy_LR" : accuracy_LR,
    "Standard Deviation" : standard_deviation_LR,
    "Sensitivity_LR" : sensitivity_LR,
    "Specificity_LR" : specificity_LR,
    "Precision_LR" : precision_LR,
    "F1_LR" : f1_LR,
    "AUROC_LR" : auroc_LR,
    "AUPR_LR" : aupr_LR,
    "Accuracy_bagging" : accuracy_bagging,
    "Standard Deviation" : standard_deviation_bagging,
    "Sensitivity_bagging" : sensitivity_bagging,
    "Specificity_bagging" : specificity_bagging,
    "Precision_bagging" : precision_bagging,
    "F1_bagging" : f1_bagging,
    "AUROC_bagging" : auroc_bagging,
    "AUPR_bagging" : aupr_bagging,
    "Accuracy_stacking" : accuracy_stacking,
    "Standard Deviation" : standard_deviation_stacking,
    "Sensitivity_stacking" : sensitivity_stacking,
    "Specificity_stacking" : specificity_stacking,
    "Precision_stacking" : precision_stacking,
    "F1_stacking" : f1_stacking,
    "AUROC_stacking" : auroc_stacking,
    "AUPR_stacking" : aupr_stacking,
}

with open("metrics.txt", "a") as f:
    f.write("Dataset 2 \n")
    for metric, value in metrics.items():
        f.write(f"{metric}: {value}\n")
